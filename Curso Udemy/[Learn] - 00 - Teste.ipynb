# %%
from pyspark.sql import functions as f
from pyspark.sql import types as t

# %%
data = spark.sql("SELECT * FROM samples.accuweather.forecast_daily_calendar_imperial")

# %%
data.printSchema()
# Out:
# root
#  |-- city_name: string (nullable = true)
#  |-- country_code: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- date: date (nullable = true)
#  |-- cloud_cover_perc_avg: integer (nullable = true)
#  |-- cloud_cover_perc_max: integer (nullable = true)
#  |-- cloud_cover_perc_min: integer (nullable = true)
#  |-- degree_days_cooling: double (nullable = true)
#  |-- degree_days_freezing: double (nullable = true)
#  |-- degree_days_growing: double (nullable = true)
#  |-- degree_days_heating: double (nullable = true)
#  |-- humidity_relative_avg: double (nullable = true)
#  |-- humidity_relative_max: double (nullable = true)
#  |-- humidity_relative_min: double (nullable = true)
#  |-- index_air_quality_24hr_max: double (nullable = true)
#  |-- index_uv_avg: double (nullable = true)
#  |-- index_uv_max: double (nullable = true)
#  |-- index_uv_min: double (nullable = true)
# ...

# %%
subset = data.groupBy("date").agg(f.sum("cloud_cover_perc_max").alias("cloud_cover_perc_max_sum")).orderBy("date")

# %%
subset.plot.line("date", "cloud_cover_perc_max_sum").show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
